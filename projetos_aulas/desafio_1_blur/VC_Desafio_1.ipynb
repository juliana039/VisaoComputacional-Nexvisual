# %% [markdown]
# ## Desafio 1 da Trilha de Visão Computacional
#
# Nesse desafio você irá implementar uma solução simples para borrar o fundo de uma imagem como uma pessoa, semelhante ao que aplicativos de vídeo chamadas fazem hoje em dia.
#
# Para isso você deverá seguir os pasos desse documento atentamente.

# %% [markdown]
# ### Instalação e Importação da Biblioteca

# %%
# %pip install opencv-python matplotlib
# Out:
# Requirement already satisfied: opencv-python in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (4.13.0.92)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (3.11.0)
# Requirement already satisfied: numpy>=2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from opencv-python) (2.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip3 install --upgrade pip

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Ler Imagens

# %%
image_bgr = cv2.imread("/Users/julianapereirademagalhaes/Downloads/visaocomp/projetos_aulas/desafio_1_blur/desafio_1.jpeg")# Leia a imagem do caminho absoluto acima.
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)   # Converta a imagem de BGR para RGB para visualização.
plt.imshow(image_rgb)

# %% [markdown]
# ### Transformar em Escala de Cinza

# %%
image_gray = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)  # Converte imagem para tons de cinza.
plt.imshow(image_gray, cmap="gray")

# %% [markdown]
# ### Detectar as Faces
#
# Para isso iremos utilizar o `haar cascade` um método de detecção de faces clásscio. Mais detalhes sobre o `haar cascade` [aqui](https://docs.opencv.org/3.4/db/d28/tutorial_cascade_classifier.html)

# %%
detec = cv2.CascadeClassifier("/Users/julianapereirademagalhaes/Downloads/visaocomp/projetos_aulas/desafio_1_blur/haarcascade_frontalface_default.xml")
face = detec.detectMultiScale(image_gray, 1.3, 3)
copy_image_rgb = image_rgb.copy()

padding = 25 # Defina quantos pixels de padding nas duas direções

for (x, y, larg, alt) in face: #Desenhar o retângulo
    ret = cv2.rectangle(copy_image_rgb, (x, y), (x + larg, y + alt), (0, 255, 0), 3)
    y, height = max(0, y-padding), min(y+alt+padding, image_rgb.shape[0])
    x, width = max(0, x-padding), min(x+larg+padding, image_rgb.shape[1])
    face_img = image_rgb[y:height,x:width,:]
plt.imshow(copy_image_rgb)

# %%
plt.imshow(face_img)

# %% [markdown]
# ### Borrar a Imagem inteira

# %%
blured_image = cv2.GaussianBlur(image_rgb, (15, 15), 0)  # Borre a imagem inteira utilizando a função GaussianBlur.
plt.imshow(blured_image)

# %% [markdown]
# ### Substituir Imagem Original da Face na Imagem Borrada

# %%
# Monte a imagem final com imagem borrada e na região da face coloce a imagem original.
final_image = blured_image # Imagem borrada.
final_image[y:height, x:width] = face_img  # região da face recebe a imagem da face original.
plt.imshow(final_image)
